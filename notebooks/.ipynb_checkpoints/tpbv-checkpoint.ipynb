# %%
import numpy as np, matplotlib.pyplot as plt
import sys; sys.path.append("../src2")
from pendulum import *

# %%
x0 = np.array([0,0,np.pi,0])
xf = np.array([0,0,0,0])
dv = np.hstack(([10], np.random.uniform(-1, 1, 4)))

# %%
dv, feas, t, y, f, u = solve(x0, xf, 0, dv=[10.24919222,  0.19457643,  0.75414392,  0.96063895,  0.84714559], Tlb=7, Tub=15, atol=1e-8, rtol=1e-8)

# %%
ax = plot_traj(y)
ax = plot_controls(t, u)

# %%
T = t[-1]
xl0 = y[:,0]
# Out:
# array([0.        , 0.        , 3.14159265, 0.        , 0.19457643,
#        0.75414392, 0.96063895, 0.84714559])
