# %%
import sys; sys.path.append("../src2")
from pendulum import *
import numpy as np, matplotlib.pyplot as plt
from scipy.optimize import newton

# %%
class srinivasan(object):
    
    def __init__(self, kx, kv, kt, kw, um):
        
        # gains
        self.kx = kx
        self.kv = kv
        self.kt = kt
        self.kw = kw
        
        # max input
        self.um = um
        
        # initial reference angle
        self.tr = 0
        
        # theta tildes
        self.ttl = np.array([newton(lambda tt: self.eq_tt(tt, tr), np.pi) for tr in [-2*np.pi, 0, 2*np.pi]])
        self.init = False
        
    def eq_tt(self, tt, tr):
        xm = np.pi**2*(np.pi+self.um)
        vm = np.pi*self.um
        return self.kt*(tt-tr) + np.sin(tt) + self.kt*np.arctan(self.kx*xm + self.kv*vm) - self.um*np.cos(tt)
    
    def gen_tt(self, tr):
        if tr == -2*np.pi:
            return self.ttl[0]
        elif tr == 0:
            return self.ttl[1]
        else:
            return self.ttl[2]
        
    def gen_tr(self, t, tr):
        dt = t - tr
        tt = self.gen_tt(tr)
        if -np.pi <= dt and dt < -tt:
            return tr - np.pi
        elif -tt <= dt and dt <= tt:
            return tr
        elif tt < dt and np.pi:
            return tr + np.pi
        
    def gen_u(self, state, tr):
        x, v, t, w = state
        uus = self.kt*(t-tr) + self.kw*w + np.sin(t) + self.kt*np.arctan(self.kx*x + self.kv*v)
        u = np.clip(uus, -self.um, self.um)
        return u
    
    def __call__(self, time, state):
        return self.gen_u(state, self.tr)
    
    def control(self, time, state):
        x, v, t, w = state
        
        
        u = self.gen_u(state, self.tr)
        self.tr = self.gen_tr(t, self.tr)
        print(self.tr)
        return u

# %%
cont = srinivasan(0, 0, 13, 1.6, 5)
tt = np.linspace(0,np.pi,500)
for tr in [-2*np.pi, 0, 2*np.pi]:
    plt.plot(tt, cont.eq_tt(tt, tr))

# %%
#0.01, 0.01, 0.4, 0.1
cont = srinivasan(0.001, 0.001, 15.1, 5.1, 5)
x0 = [0,0,np.pi,0]
dyn  = dynamics(x0,[0,0,0,0], 0)

# %%
t, x, u = dyn.propagate_controlled(14, cont)
plot_traj(x, arm=True, n=500)
ax = plot_controls(t, u)
fig, ax = plt.subplots(1)
ax.plot(t, cont.trl)
# Out:
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-5d4e722009f4> in <module>()
# ----> 1 t, x, u = dyn.propagate_controlled(14, cont)
#       2 plot_traj(x, arm=True, n=500)
#       3 ax = plot_controls(t, u)
#       4 fig, ax = plt.subplots(1)
#       5 ax.plot(t, cont.trl)
#
# ~/Dev/icra2019/src2/pendulum.py in propagate_controlled(self, T, controller)
#     265
#     266         while integrator.status is 'running':
# --> 267             integrator.step()
#     268             tl.append(integrator.t)
#     269             xl.append(integrator.y)
#
# /usr/lib/python3.7/site-packages/scipy/integrate/_ivp/base.py in step(self)
#     180         else:
#     181             t = self.t
# --> 182             success, message = self._step_impl()
#     183
#     184             if not success:
#
# /usr/lib/python3.7/site-packages/scipy/integrate/_ivp/rk.py in _step_impl(self)
#     137
#     138             y_new, f_new, error = rk_step(self.fun, t, y, self.f, h, self.A,
# --> 139                                           self.B, self.C, self.E, self.K)
#     140             scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     141             error_norm = norm(error / scale)
#
# /usr/lib/python3.7/site-packages/scipy/integrate/_ivp/rk.py in rk_step(fun, t, y, f, h, A, B, C, E, K)
#      68     for s, (a, c) in enumerate(zip(A, C)):
#      69         dy = np.dot(K[:s + 1].T, a) * h
# ---> 70         K[s + 1] = fun(t + c * h, y + dy)
#      71
#      72     y_new = y + h * np.dot(K[:-1].T, B)
#
# /usr/lib/python3.7/site-packages/scipy/integrate/_ivp/base.py in fun(t, y)
#     137         def fun(t, y):
#     138             self.nfev += 1
# --> 139             return self.fun_single(t, y)
#     140
#     141         self.fun = fun
#
# /usr/lib/python3.7/site-packages/scipy/integrate/_ivp/base.py in fun_wrapped(t, y)
#      19
#      20     def fun_wrapped(t, y):
# ---> 21         return np.asarray(fun(t, y), dtype=dtype)
#      22
#      23     return fun_wrapped, y0
#
# ~/Dev/icra2019/src2/pendulum.py in <lambda>(t, x)
#     251
#     252         integrator = RK45(
# --> 253             lambda t, x: self.dxdt(x, controller(t, x)),
#     254             0,
#     255             self.x0,
#
# <ipython-input-61-4f6760fa1305> in __call__(self, time, state)
#      48
#      49     def __call__(self, time, state):
# ---> 50         return self.gen_u(state, self.tr)
#      51
#      52     def control(self, time, state):
#
# <ipython-input-61-4f6760fa1305> in gen_u(self, state, tr)
#      43     def gen_u(self, state, tr):
#      44         x, v, t, w = state
# ---> 45         uus = self.kt*(t-tr) + self.kw*w + np.sin(t) + self.kt*np.arctan(self.kx*x + self.kv*v)
#      46         u = np.clip(uus, -self.um, self.um)
#      47         return u
#
# TypeError: unsupported operand type(s) for -: 'float' and 'NoneType'

# %%
-5%np.pi
